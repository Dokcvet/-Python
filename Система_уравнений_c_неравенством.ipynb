# %%
# %matplotlib inline
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10, 10))
x = np.linspace(-5, 5, 100)
plt.plot(x, np.exp(x) + x*(2-x**2) - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-4, 6) 
plt.grid(True)
plt.show()
#Ответ: (-∞, 1.58; 0, 2.62; 4.2, +∞)
